# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import LineString

# %%
# %matplotlib inline

# %%
df = pd.read_csv("JSON_OUTPUT21.csv")

# %%
# df['close'] = [ele[ : -6] for ele in df['close']]

# %%
df.drop([index for index, ele in enumerate(df['close']) if ele == ''], inplace = True)

# %%
df = df.astype({'close' : float})

# %%
df['FAST_EMA'] = df['close'].ewm(span = 20).mean()
df['SLOW_EMA'] = df['close'].ewm(span = 50).mean()

df.head()
# Out:
#    Unnamed: 0                 time        open        high         low  \
# 0           0  2021-09-21 20:00:00  122.322702  122.322702  122.193835
# 1           1  2021-09-21 19:30:00  122.295088  122.414751  122.295088
# 2           2  2021-09-21 19:00:00  122.479184  122.598847  122.258269
# 3           3  2021-09-21 18:30:00  122.368726  123.068292  122.368726
# 4           4  2021-09-21 17:30:00  122.377931  122.377931  122.295088
#
#         close  volume  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0  122.193835    3939         NaN         NaN         NaN          NaN
# 1  122.414751     313         NaN         NaN         NaN          NaN
# 2  122.423955    7595         NaN         NaN         NaN          NaN
# 3  122.451570   18725         NaN         NaN         NaN          NaN
# 4  122.295088     417         NaN         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12    FAST_EMA    SLOW_EMA
# 0          NaN          NaN  122.193835  122.193835
# 1          NaN          NaN  122.309816  122.306502
# 2          NaN          NaN  122.351727  122.347229
# 3          NaN          NaN  122.380550  122.374900
# 4          NaN          NaN  122.359878  122.357636

# %%
df.drop(df.columns[[7, 8, 9, 10, 11, 12]], axis = 1, inplace = True)

# %%
plt.figure(figsize=(20, 10))
plt.style.use('Solarize_Light2')

x = df['Unnamed: 0']
y1 = df['FAST_EMA']
y2 = df['SLOW_EMA']

plt.plot(x, y1, '-')
plt.plot(x, y2, '-')

# %%
first_line = LineString(np.column_stack((x, y1)))
second_line = LineString(np.column_stack((x, y2)))
intersection = first_line.intersection(second_line)

plt.figure(figsize=(20, 10))

plt.plot(x, y1)
plt.plot(x, y2)

if intersection.geom_type == 'MultiPoint':
    plt.plot(*LineString(intersection).xy, 'o')
elif intersection.geom_type == 'Point':
    plt.plot(*intersection.xy, 'o')

# %%
df.info()
plt.figure(figsize=(150, 150))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11984 entries, 0 to 11983
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11984 non-null  int64
#  1   time        11984 non-null  object
#  2   open        11984 non-null  float64
#  3   high        11984 non-null  float64
#  4   low         11984 non-null  float64
#  5   close       11984 non-null  float64
#  6   volume      11984 non-null  int64
#  7   FAST_EMA    11984 non-null  float64
#  8   SLOW_EMA    11984 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 936.2+ KB

# %%
b = True
capital = 10000
indexes = [0]

# lst = [0]*len(df["close"])

units = (capital/df["close"][0]) # units bought

df[['SLOW_EMA', 'FAST_EMA']].plot(figsize=(20, 12))
plt.xlabel('Number of data points')
plt.ylabel('Moving Averages')
prev = 0
for i in range(1, len(df["close"])):
    current_pnl = 0
    
    # selling condition
    if b and df["SLOW_EMA"][i] > df["FAST_EMA"][i] and df["SLOW_EMA"][i - 1] < df["FAST_EMA"][i - 1]:
        b = False
        current_pnl = units*df["close"][i] - prev
        capital = capital + current_pnl
        plt.plot(i,df["SLOW_EMA"][i],'ro') 
        indexes.append(i)

    # buying condition
    elif not b and df["SLOW_EMA"][i] < df["FAST_EMA"][i] and df["SLOW_EMA"][i - 1] > df["FAST_EMA"][i - 1]:
        b = True
        units = (capital//df["close"][i])
        prev = units * df['close'][i]
        plt.plot(i,df["SLOW_EMA"][i], 'go') 
        indexes.append(i)
    
    lst[i] += (current_pnl + lst[i - 1])

# %%
df['PnL'] = lst

# %%
df
# Out:
#             close    FAST_EMA    SLOW_EMA          PnL
# 0      122.193835  122.193835  122.193835     0.000000
# 1      122.414751  122.309816  122.306502     0.000000
# 2      122.423955  122.351727  122.347229     0.000000
# 3      122.451570  122.380550  122.374900     0.000000
# 4      122.295088  122.359878  122.357636     0.000000
# ...           ...         ...         ...          ...
# 11979  130.120000  128.287501  129.589720  5547.292205
# 11980  130.520000  128.500120  129.626202  5547.292205
# 11981  130.800000  128.719156  129.672233  5547.292205
# 11982  130.980000  128.934474  129.723518  5547.292205
# 11983  130.680000  129.100715  129.761027  5547.292205
#
# [11984 rows x 4 columns]

# %%
dict1 = {'close' : [], 'PnL' : [], 'Profit/Loss' : []}
j = 0
for index in indexes:
    dict1['PnL'].append(df['PnL'][index])
    dict1['close'].append(df['close'][index])
    
    if j%2 == 1 and df['close'][indexes[j]] > df['close'][indexes[j - 1]]:
        dict1['Profit/Loss'].append(1)
    elif j%2 == 1 and df['close'][indexes[j]] < df['close'][indexes[j - 1]]:
        dict1['Profit/Loss'].append(0)
    else:
        dict1['Profit/Loss'].append(np.NaN)

    j += 1
# print(indexes)
# print(df['close'][35], df['close'][0])

# %%
df2 = pd.DataFrame.from_dict(dict1)
df2
# Out:
#           close           PnL  Profit/Loss
# 0    122.193835      0.000000          NaN
# 1    122.847377  10053.483992          1.0
# 2    124.090026  10053.483992          NaN
# 3    122.884196   9859.345373          0.0
# 4    124.476628   9859.345373          NaN
# ..          ...           ...          ...
# 227  135.375000   5355.032205          0.0
# 228  136.045000   5355.032205          NaN
# 229  134.000000   5125.992205          0.0
# 230  137.270000   5125.992205          NaN
# 231  141.100000   5547.292205          1.0
#
# [232 rows x 3 columns]

# %%
df.drop(['time', 'open', 'high', 'low', 'volume'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-dba6924178e8> in <module>
# ----> 1 df.drop(['time', 'open', 'high', 'low', 'volume'], axis = 1, inplace = True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['time' 'open' 'high' 'low' 'volume'] not found in axis"

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#             close    FAST_EMA    SLOW_EMA          PnL
# 0      122.193835  122.193835  122.193835     0.000000
# 1      122.414751  122.309816  122.306502     0.000000
# 2      122.423955  122.351727  122.347229     0.000000
# 3      122.451570  122.380550  122.374900     0.000000
# 4      122.295088  122.359878  122.357636     0.000000
# ...           ...         ...         ...          ...
# 11979  130.120000  128.287501  129.589720  5547.292205
# 11980  130.520000  128.500120  129.626202  5547.292205
# 11981  130.800000  128.719156  129.672233  5547.292205
# 11982  130.980000  128.934474  129.723518  5547.292205
# 11983  130.680000  129.100715  129.761027  5547.292205
#
# [11984 rows x 4 columns]
